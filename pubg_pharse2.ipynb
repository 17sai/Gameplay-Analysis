# %% [markdown]
# # Phase 2: Data Cleaning & Manipulation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = pd.read_csv("pubg3.csv")
a
# Out:
#        Unnamed: 0.1  Unnamed: 0  assists  boosts  damageDealt  kills  \
# 0                 0           0      NaN     1.0          NaN    2.0
# 1                 1           1      0.0     0.0         0.00    0.0
# 2                 2           2      0.0     0.0         0.00    0.0
# 3                 3           3      0.0     0.0        72.32    0.0
# 4                 4           4      0.0     0.0         0.00    0.0
# ...             ...         ...      ...     ...          ...    ...
# 49445         49445       49995      0.0     0.0          NaN    0.0
# 49446         49446       49996      0.0     NaN       100.00    1.0
# 49447         49447       49997      0.0     NaN          NaN    2.0
# 49448         49448       49998      0.0     0.0       175.00    2.0
# 49449         49449       49999      0.0     0.0         0.00    0.0
#
#        walkDistance  swimDistance  weaponsAcquired  revives match_category  \
# ...

# %%
a.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1,inplace=True)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49450 entries, 0 to 49449
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   assists          42850 non-null  float64
#  1   boosts           42011 non-null  float64
#  2   damageDealt      45951 non-null  float64
#  3   kills            45911 non-null  float64
#  4   walkDistance     43886 non-null  float64
#  5   swimDistance     41258 non-null  float64
#  6   weaponsAcquired  45760 non-null  float64
#  7   revives          41204 non-null  float64
#  8   match_category   40724 non-null  object
#  9   performance_tag  44961 non-null  object
#  10  distance_type    43218 non-null  object
#  11  healing_style    40842 non-null  object
#  12  kill_style       20176 non-null  object
#  13  winPlacePerc     40720 non-null  float64
# dtypes: float64(9), object(5)
# memory usage: 5.3+ MB

# %% [markdown]
# # Handle Missing Data

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49450 entries, 0 to 49449
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   assists          42850 non-null  float64
#  1   boosts           42011 non-null  float64
#  2   damageDealt      45951 non-null  float64
#  3   kills            45911 non-null  float64
#  4   walkDistance     43886 non-null  float64
#  5   swimDistance     41258 non-null  float64
#  6   weaponsAcquired  45760 non-null  float64
#  7   revives          41204 non-null  float64
#  8   match_category   40724 non-null  object
#  9   performance_tag  44961 non-null  object
#  10  distance_type    43218 non-null  object
#  11  healing_style    40842 non-null  object
#  12  kill_style       20176 non-null  object
#  13  winPlacePerc     40720 non-null  float64
# dtypes: float64(9), object(5)
# memory usage: 5.3+ MB

# %%
a["assists"].isnull().sum()
# Out:
# 0

# %% [markdown]
# - here missing values are replaced with median because of discreate numeric values.

# %%
a["assists"] = a["assists"].fillna(a["assists"].median())

# %%
a["boosts"].isnull().sum()
# Out:
# 7439

# %% [markdown]
# - here missing values are replaced with median because of discreate numeric values.

# %%
a["boosts"] = a["boosts"].fillna(a["boosts"].median())

# %%
a["damageDealt"].isnull().sum()
# Out:
# 3499

# %% [markdown]
# - here missing values are replaced with mean because of continuous numeric values.

# %%
a["damageDealt"] = a["damageDealt"].fillna(a["damageDealt"].mean())

# %%
a["kills"].isnull().sum()
# Out:
# 3539

# %% [markdown]
# - here missing values are replaced with median because of discreate numeric values.

# %%
a["kills"] = a["kills"].fillna(a["kills"].median())

# %%
a["walkDistance"].isnull().sum()
# Out:
# 5564

# %% [markdown]
# - here missing values are replaced with mean because of continuous numeric values.

# %%
a["walkDistance"] = a["walkDistance"].fillna(a["walkDistance"].mean())

# %%
a["swimDistance"].isnull().sum()
# Out:
# 8192

# %% [markdown]
# - here missing values are replaced with median because of discreate numeric values.

# %%
a["swimDistance"] = a["swimDistance"].fillna(a["swimDistance"].median())

# %%
a["weaponsAcquired"].isnull().sum()
# Out:
# 3690

# %% [markdown]
# - here missing values are replaced with median because of almost descrete numeric values.

# %%
a["weaponsAcquired"] = a["weaponsAcquired"].fillna(a["weaponsAcquired"].median())

# %%
a["revives"].isnull().sum()
# Out:
# 8246

# %% [markdown]
# - here missing values are replaced with median because of descrete numeric values.

# %%
a["revives"] = a["revives"].fillna(a["revives"].median())

# %%
a["match_category"].isnull().sum()
# Out:
# 0

# %% [markdown]
# - here missing values are replaced by mode because of categorical data.

# %%
a["match_category"] = a["match_category"].fillna(a["match_category"].mode()[0])

# %%
a["performance_tag"].isnull().sum()
# Out:
# 4489

# %% [markdown]
# - here missing values are replaced by mode because of categorical data.

# %%
a["performance_tag"] = a["performance_tag"].fillna(a["performance_tag"].mode()[0])

# %%
a["distance_type"].isnull().sum()
# Out:
# 6232

# %% [markdown]
# - here missing values are replaced by mode because of categorical data.

# %%
a["distance_type"] = a["distance_type"].fillna(a["distance_type"].mode()[0])

# %%
a["healing_style"].isnull().sum()
# Out:
# 8608

# %% [markdown]
# - here missing values are replaced by mode because of categorical data.

# %%
a["healing_style"] = a["healing_style"].fillna(a["healing_style"].mode()[0])

# %%
a["kill_style"].isnull().sum()
# Out:
# 29274

# %% [markdown]
# - here missing values are replaced by mode because of categorical data.

# %%
a["kill_style"] = a["kill_style"].fillna(a["kill_style"].mode()[0])

# %%
a["winPlacePerc"].isnull().sum()
# Out:
# 8730

# %% [markdown]
# - here missing values are replaced with mean because of continuous numeric values.

# %%
a["winPlacePerc"] = a["winPlacePerc"].fillna(a["winPlacePerc"].mean())

# %%
a.isnull().sum()
# Out:
# assists            0
# boosts             0
# damageDealt        0
# kills              0
# walkDistance       0
# swimDistance       0
# weaponsAcquired    0
# revives            0
# match_category     0
# performance_tag    0
# distance_type      0
# healing_style      0
# kill_style         0
# winPlacePerc       0
# dtype: int64

# %% [markdown]
# # Remove Duplicates

# %%
a.duplicated().sum()
# Out:
# 623

# %%
a.drop_duplicates(inplace=True)

# %%
a.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Fix Inconsistencies in Categorical Data

# %% [markdown]
# - As there are 5 object data columns are present need to check inconsistencies.

# %%
a["match_category"].unique()
# Out:
# array(['Platinum', 'Silver', 'Bronze', 'Gold'], dtype=object)

# %% [markdown]
# - There are No inconsistencies present in "match_category" column.

# %%
a["performance_tag"].unique()
# Out:
# array(['Passive', 'Aggressive'], dtype=object)

# %% [markdown]
# - There are No inconsistencies present in "performance_tag" column.

# %%
a["distance_type"].unique()
# Out:
# array(['High', 'Medium', 'Low', 'VeryLow'], dtype=object)

# %% [markdown]
# - There are No inconsistencies present in "distance_type" column.

# %%
a["healing_style"].unique()
# Out:
# array(['LowHeal', 'NoHeal', 'HighHeal'], dtype=object)

# %% [markdown]
# - There are No inconsistencies present in "healing_style" column.

# %%
a["kill_style"].unique()
# Out:
# array(['Normal', 'Headshot'], dtype=object)

# %% [markdown]
# - There are No inconsistencies present in "kill_style" column.

# %% [markdown]
# # Convert Data Types

# %%
a["assists"] = a["assists"].astype("int")

# %%
a["boosts"] = a["boosts"].astype("int")

# %%
a["kills"] = a["kills"].astype("int")

# %%
a["weaponsAcquired"] = a["weaponsAcquired"].astype("int")

# %%
a["revives"] = a["revives"].astype("int")

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48827 entries, 0 to 49449
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   assists          48827 non-null  int64
#  1   boosts           48827 non-null  int64
#  2   damageDealt      48827 non-null  float64
#  3   kills            48827 non-null  int64
#  4   walkDistance     48827 non-null  float64
#  5   swimDistance     48827 non-null  float64
#  6   weaponsAcquired  48827 non-null  int64
#  7   revives          48827 non-null  int64
#  8   match_category   48827 non-null  object
#  9   performance_tag  48827 non-null  object
#  10  distance_type    48827 non-null  object
#  11  healing_style    48827 non-null  object
#  12  kill_style       48827 non-null  object
#  13  winPlacePerc     48827 non-null  float64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 5.6+ MB

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Categorical data

# %%
# 1. kill_style → Pie Chart
plt.figure(figsize=(6,6))
a['kill_style'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette("Set2"))
plt.title("Distribution of Kill Styles")
plt.ylabel("")
plt.show()

# %%
# 2. match_category → Countplot
plt.figure(figsize=(7,4))
sns.countplot(data=a, x="match_category", order=a["match_category"].value_counts().index, palette="viridis")
plt.title("Match Category Distribution")
plt.show()
# Out:
# /var/folders/ts/2fk00y9s3yd_bbtmwh9z_x580000gn/T/ipykernel_2017/2071840362.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=a, x="match_category", order=a["match_category"].value_counts().index, palette="viridis")

# %%
# 3. healing_style → Bar Chart
plt.figure(figsize=(7,4))
a['healing_style'].value_counts().plot(kind='bar', color="teal")
plt.title("Healing Style Frequency")
plt.ylabel("Count")
plt.show()

# %%
# 4. distance_type → Countplot
plt.figure(figsize=(7,4))
sns.countplot(data=a, x="distance_type", palette="muted")
plt.title("Distance Type Distribution")
plt.show()
# Out:
# /var/folders/ts/2fk00y9s3yd_bbtmwh9z_x580000gn/T/ipykernel_2017/1769210159.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=a, x="distance_type", palette="muted")

# %%
# 5. performance_tag → Pie Chart
plt.figure(figsize=(6,6))
a['performance_tag'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette("coolwarm"))
plt.title("Performance Tag Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Numerical data

# %%
# 6. kills → Histogram + KDE
plt.figure(figsize=(7,4))
sns.histplot(a['kills'], bins=30, kde=True, color="skyblue")
plt.title("Kills Distribution")
plt.show()

# %%
# 7. damageDealt → Boxplot
plt.figure(figsize=(7,3))
sns.boxplot(x=a['damageDealt'], color="orange")
plt.title("Damage Dealt Boxplot")
plt.show()

# %%
# 8. walkDistance → Histogram
plt.figure(figsize=(7,4))
sns.histplot(a['walkDistance'], bins=30, color="purple", kde=False)
plt.title("Walk Distance Distribution")
plt.show()

# %%
# 9. swimDistance → Histogram
plt.figure(figsize=(7,4))
sns.histplot(a['swimDistance'], bins=30, color="green", kde=False)
plt.title("Swim Distance Distribution")
plt.show()

# %%
# 10. assists → Countplot
plt.figure(figsize=(7,4))
sns.countplot(data=a, x="assists", palette="Set1")
plt.title("Assists Count Distribution")
plt.show()
# Out:
# /var/folders/ts/2fk00y9s3yd_bbtmwh9z_x580000gn/T/ipykernel_2017/3784933249.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=a, x="assists", palette="Set1")

# %%
# 11. revives → Countplot
plt.figure(figsize=(7,4))
sns.countplot(data=a, x="revives", palette="Set2")
plt.title("Revives Count Distribution")
plt.show()
# Out:
# /var/folders/ts/2fk00y9s3yd_bbtmwh9z_x580000gn/T/ipykernel_2017/1290253335.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=a, x="revives", palette="Set2")

# %%
# 12. winPlacePerc → KDE Plot
plt.figure(figsize=(7,4))
sns.kdeplot(a['winPlacePerc'], fill=True, color="blue", alpha=0.4)
plt.title("Win Percentage Distribution")
plt.xlabel("Win Place Percentage")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# 1. Categorical vs Categorical → Countplot
plt.figure(figsize=(8,5))
sns.countplot(data=a, x="match_category", hue="distance_type")
plt.title("Match Category vs Distance Type")
plt.xticks(rotation=45)
plt.show()

# %%
# 2. Categorical vs Numerical → Boxplot
plt.figure(figsize=(8,5))
sns.boxplot(data=a, x="match_category", y="kills")
plt.title("Kills Distribution per Match Category")
plt.xticks(rotation=45)
plt.show()

# %%
# 3. Categorical vs Numerical → Barplot (Mean values)
plt.figure(figsize=(8,5))
sns.barplot(data=a, x="healing_style", y="damageDealt", estimator="mean")
plt.title("Average Damage Dealt by Healing Style")
plt.xticks(rotation=45)
plt.show()

# %%
# 4. Numerical vs Numerical → Scatterplot
plt.figure(figsize=(8,5))
sns.scatterplot(data=a, x="walkDistance", y="winPlacePerc", alpha=0.3)
plt.title("Walk Distance vs Win Percentage")
plt.show()

# %%
# 5. Numerical vs Numerical → Correlation Heatmap
num_cols = ["kills","damageDealt","walkDistance","boosts","weaponsAcquired","winPlacePerc"]

corr_matrix = a[num_cols].corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Numerical Features")
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
# 1. Pairplot (All Numerical Variables Together)
num_cols = ["kills","damageDealt","walkDistance","swimDistance",
            "assists","revives","boosts","weaponsAcquired","winPlacePerc"]

sns.pairplot(a[num_cols], diag_kind="kde", corner=True, plot_kws={'alpha':0.3})
plt.suptitle("Pairwise Relationships Between Numerical Features", y=1.02)
plt.show()
